# %% [markdown]
# #### 예제 2.01 파이토치 버전 확인

# %%
# ipykernel 설치시 버튼설치보다 터미널에서 install하는게 나아..왜냐면 무한반복했었음..
# pip install ipykernel

# %%
import torch

print(torch.__version__)
# Out:
# 2.10.0+cpu

# %% [markdown]
# #### 예제 2.02 파이토치 GPU 가속 확인

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())

# %% [markdown]
# #### 예제 2.03 MPS(apple silicon) 가속 확인 - mac 용

# %%
import torch

print(torch.__version__)
print(torch.backends.mps.is_built())
print(torch.backends.mps.is_available())
